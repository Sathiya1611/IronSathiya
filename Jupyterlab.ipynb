# %% [markdown]
#  # Day1_JupyterLab

# %% [markdown]
# The purpose of creating this notebook is to let you know about the holidays preference and the most favorite holiday pic of my nephew.

# %% [markdown]
#  ## Input function

# %%
name = input("Enter the name of the person:")
print("The name of the person is", name)
# Out:
# Enter the name of the person:Sabil Shamsudeen
# The name of the person is Sabil Shamsudeen

# %% [markdown]
#  ## Photo of the person

# %% [markdown]
# ![sabil.JPG](attachment:sabil.JPG)

# %% [markdown]
#  ## Function to know his preferences

# %%
Preference1 = input("Please enter the first preference place:\n")
Preference2 = input("Please enter second preference place:\n")
 
p1 = preference1
p2 = preference2
 
choice = input("Enter 1 for preference1.\nEnter 2 for preference2.\n")
choice = int(choice)
 
if choice == 1:
    print(f'You entered {p1} and your favorite destination is correct')
elif choice == 2:
    print(f'You entered {p2} and the favorite destination is correct')

else:
    print("Wrong Choice, terminating the program.")

# %% [markdown]
#  ## Photo of preference destination

# %% [markdown]
# ![IMG_6744.JPG](attachment:IMG_6744.JPG)

# %% [markdown]
#  ## Things he likes to do

# %% [markdown]
#   - Swimming
#   - Family Party
#   - Friends meetup

# %% [markdown]
#  ## Text color and bold

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>  - Swimming</b>
# <b>  - Friends meeting</b>
# <b>  - Family Party</b>
# </div>

# %% [markdown]
#  ## Link of the video

# %% [markdown]
# https://www.youtube.com/watch?v=LiZY0g5RYlY
